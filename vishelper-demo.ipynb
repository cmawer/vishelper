# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#vishelper.plot-demo" data-toc-modified-id="vishelper.plot-demo-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><code>vishelper.plot</code> demo</a></span><ul class="toc-item"><li><span><a href="#Univariate-plot" data-toc-modified-id="Univariate-plot-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Univariate plot</a></span><ul class="toc-item"><li><span><a href="#Basic" data-toc-modified-id="Basic-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Basic</a></span></li><li><span><a href="#Add-labels-and-title" data-toc-modified-id="Add-labels-and-title-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Add labels and title</a></span></li><li><span><a href="#Add-histogram-specific-keywords" data-toc-modified-id="Add-histogram-specific-keywords-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Add histogram specific keywords</a></span></li></ul></li><li><span><a href="#Bivariate" data-toc-modified-id="Bivariate-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Bivariate</a></span><ul class="toc-item"><li><span><a href="#Basic-with-labels" data-toc-modified-id="Basic-with-labels-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Basic with labels</a></span></li><li><span><a href="#Multiple-datasets" data-toc-modified-id="Multiple-datasets-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Multiple datasets</a></span></li><li><span><a href="#Multiple-line-plots" data-toc-modified-id="Multiple-line-plots-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Multiple line plots</a></span></li><li><span><a href="#Change-colors" data-toc-modified-id="Change-colors-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Change colors</a></span></li><li><span><a href="#Remove-legend" data-toc-modified-id="Remove-legend-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>Remove legend</a></span></li></ul></li><li><span><a href="#Subplots" data-toc-modified-id="Subplots-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Subplots</a></span></li><li><span><a href="#Horizontal-bar-plot" data-toc-modified-id="Horizontal-bar-plot-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Horizontal bar plot</a></span><ul class="toc-item"><li><span><a href="#Multiple-values" data-toc-modified-id="Multiple-values-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Multiple values</a></span></li><li><span><a href="#Using-the-dataframe" data-toc-modified-id="Using-the-dataframe-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Using the dataframe</a></span></li></ul></li><li><span><a href="#Heatmap" data-toc-modified-id="Heatmap-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Heatmap</a></span><ul class="toc-item"><li><span><a href="#Using-vh.heatmap()-directly" data-toc-modified-id="Using-vh.heatmap()-directly-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Using <code>vh.heatmap()</code> directly</a></span></li></ul></li><li><span><a href="#Box-plots" data-toc-modified-id="Box-plots-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Box plots</a></span></li></ul></li><li><span><a href="#Demo-of-vh.vhDvhisDF" data-toc-modified-id="Demo-of-vh.vhDvhisDF-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Demo of <code>vh.vhDvhisDF</code></a></span><ul class="toc-item"><li><span><a href="#Relationship-between-categorical-and-continuous-variables-(e.g.-cluster-assigment-and-feature)" data-toc-modified-id="Relationship-between-categorical-and-continuous-variables-(e.g.-cluster-assigment-and-feature)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Relationship between categorical and continuous variables (e.g. cluster assigment and feature)</a></span><ul class="toc-item"><li><span><a href="#Calculate-lift,-percent-increase,-absolute-difference-from-population-of-group-statistics" data-toc-modified-id="Calculate-lift,-percent-increase,-absolute-difference-from-population-of-group-statistics-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Calculate lift, percent increase, absolute difference from population of group statistics</a></span></li><li><span><a href="#Heatmap-of-variable-means-by-category" data-toc-modified-id="Heatmap-of-variable-means-by-category-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Heatmap of variable means by category</a></span></li><li><span><a href="#Heatmap-of-lift" data-toc-modified-id="Heatmap-of-lift-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Heatmap of lift</a></span></li></ul></li><li><span><a href="#Box-plots" data-toc-modified-id="Box-plots-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Box plots</a></span></li><li><span><a href="#Subplots" data-toc-modified-id="Subplots-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Subplots</a></span><ul class="toc-item"><li><span><a href="#Same-type-of-plot" data-toc-modified-id="Same-type-of-plot-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Same type of plot</a></span></li><li><span><a href="#Different-types-of-plots" data-toc-modified-id="Different-types-of-plots-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Different types of plots</a></span></li><li><span><a href="#Subplots-with-categorical-counts" data-toc-modified-id="Subplots-with-categorical-counts-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Subplots with categorical counts</a></span></li></ul></li></ul></li></ul></div>

# %%
# must go first
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# Reloads functions each time so you can edit a script 
# and not need to restart the kernel
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings('ignore')

# %%
import vishelper as vh

# %%
data = datasets.load_boston()

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)

# %%
print(data.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(df.values)
df['cluster'] = kmeans.labels_

# %% [markdown]
# # `vishelper.plot` demo

# %% [markdown]
# ```fig, ax = vh.plot(x, y=None, kind=None, plot_function=None, ax=None,
#                      xlabel=None, ylabel=None, title=None, legend=True,
#                      labels=None, color=None, **kwargs)```

# %% [markdown]
# * Univariate or bivariate
# * Type of plot given either by `kind` (str) or `plot_function` (function that takes and returns `ax`)
# * `kwargs` can be any keyword that can be taken by the plot function

# %% [markdown]
# ## Univariate plot

# %% [markdown]
# ### Basic

# %%
fig1, ax1 = vh.plot(df.RM, kind='hist')

# %% [markdown]
# ### Add labels and title

# %%
fig1, ax1 = vh.plot(df.RM, kind='hist', 
                 xlabel='Average number of rooms per dwelling',
                 ylabel='Count',
                 title='Distribution of average number of rooms per dwelling')

# %% [markdown]
# ### Add histogram specific keywords

# %%
fig1, ax1 = vh.plot(df.RM, kind='hist', 
                 xlabel='Average number of rooms per dwelling',
                 ylabel='Count',
                 title='Distribution of average number of rooms per dwelling',
                 bins=20)

# %% [markdown]
# ## Bivariate

# %% [markdown]
# ### Basic with labels

# %%
fig2, ax2 =vh.plot(df.RM, df.CRIM, 
                 kind='scatter', xlabel='Average number of rooms per dwelling',
                 ylabel='Per-capita crime rate', 
                 title='Average number of rooms per dwelling vs per-capita crime rate')

# %% [markdown]
# ### Multiple datasets

# %%
X = df.groupby('cluster').RM.apply(list).tolist()

# %%
Y = df.groupby('cluster').CRIM.apply(list).tolist()

# %%
fig2, ax2 = vh.plot(
    X,
    Y,
    kind='scatter',
    xlabel='Average number of rooms per dwelling',
    ylabel='Per-capita crime rate',
    title='Average number of rooms per dwelling vs per-capita crime rate',
    alpha=0.4,
    legend=True)

# %% [markdown]
# ### Multiple line plots

# %%
fig2, ax2 = vh.plot(
    X,
    Y,
    kind='line',
    xlabel='Average number of rooms per dwelling',
    ylabel='Per-capita crime rate',
    title='Average number of rooms per dwelling vs per-capita crime rate',
    alpha=0.4,
    legend=True,
    labels=["Test label %i" % j for j in range(len(X)) ])

# %% [markdown]
# ### Change colors

# %%
fig2, ax2 = vh.plot(X, Y, kind='scatter', xlabel='Average number of rooms per dwelling',
                 ylabel='Per-capita crime rate', 
                 title='Average number of rooms per dwelling vs per-capita crime rate',
                alpha=0.4)

# %% [markdown]
# ### Remove legend

# %%
fig2, ax2 =vh.plot(X, Y, 
                 kind='scatter', xlabel='Average number of rooms per dwelling',
                 ylabel='Per-capita crime rate', 
                 title='Average number of rooms per dwelling vs per-capita crime rate',
                 alpha=0.4, 
                 legend=False)

# %% [markdown]
# ## Subplots

# %%
fig, axes = plt.subplots(2,2,figsize=(14,12))
axes[0,0] = vh.plot(df.RM, kind='hist', 
                 xlabel='Average number of rooms per dwelling',
                 ylabel='Count',
                 title='Distribution of average number of rooms per dwelling',
                 bins=20, 
             ax=axes[0,0])
axes[1,0] = vh.plot(X, Y, 
                 kind='scatter', xlabel='Average number of rooms per dwelling',
                 ylabel='Per-capita crime rate', 
                 title='Average number of rooms per dwelling vs per-capita crime rate',
                 alpha=0.4, 
                 legend=False,
            ax=axes[1,0])
axes[0,0] = vh.add_vline(axes[0,0], 6)

# %% [markdown]
# ## Horizontal bar plot

# %%
means = df.groupby('cluster').mean()

# %%
fig, ax = vh.plot(means.index, means.CRIM.values, 
                  kind='barh', ylabel='Cluster number', 
                  xlabel='Per-capita crime rate',
                  title='Average per-capita crime rate of towns by cluster')

# %%
fig, ax = vh.plot('cluster', ['CRIM', 'ZN'], means.reset_index(),
                  kind='barh', ylabel='Cluster number', 
                  xlabel='Per-capita crime rate',
                  title='Average per-capita crime rate of towns by cluster',
                 alpha=0.5)

# %% [markdown]
# ### Multiple values

# %%
river_means = df.groupby(['CHAS', 'cluster']).mean()

# %%
river_means = river_means.unstack().T

# %%
river_means.head()
# Out:
# CHAS                0.0       1.0
#      cluster
# CRIM 0         0.545340  1.747955
#      1        16.346086       NaN
#      2        11.347501  5.775886
#      3         0.235937  0.228931
#      4         1.806027  3.535010

# %%
fig, ax = vh.plot(
    river_means.loc['CRIM'].index,
    [river_means.loc['CRIM'][0.0].values, river_means.loc['CRIM'][1.0].values],
    kind='barh',
    ylabel='Cluster',
    xlabel='Per-capita crime rate',
    title='Average per-capita crime rate of towns along the river and not',
    labels=["On the river", "Not on the river"])

# %% [markdown]
# ### Using the dataframe

# %%
fig, ax = vh.plot(
    x="cluster",
    y=[0.0, 1.0],
    df=river_means.loc['CRIM'].reset_index(),
    kind='barh',
    ylabel='Cluster',
    xlabel='Per-capita crime rate',
    title='Average per-capita crime rate of towns along the river and not',
    labels=["On the river", "Not on the river"])

# %%
fig, ax = vh.plot(
    x=["cluster", "cluster"],
    y=[0.0, 1.0],
    df=river_means.loc['CRIM'].reset_index(),
    kind='barh',
    ylabel='Cluster',
    xlabel='Per-capita crime rate',
    title='Average per-capita crime rate of towns along the river and not',
    labels=["On the river", "Not on the river"])

# %%
ax.bar(
        list(df.index.values),
        df[df.columns[i]].values,
        bottom=df.loc[:, df.columns[0]:df.columns[i]].sum(axis=1).values -
               df.loc[:, df.columns[i]].values,
        color=color,
        label=label,
        **kwargs);

# %%
x = df.index.tolist()
y = df.iloc[:, i].values

# %%
river_means.loc['CRIM'].index.tolist()
# Out:
# [0, 1, 2, 3, 4]

# %%
river_means.loc['CRIM']
# Out:
# CHAS           0.0       1.0
# cluster
# 0         0.545340  1.747955
# 1        16.346086       NaN
# 2        11.347501  5.775886
# 3         0.235937  0.228931
# 4         1.806027  3.535010

# %%
lift.T
# Out:
# cluster         0         1         2         3         4
# CRIM     0.171292  4.523586  3.019355  0.065144  0.543294
# ZN       1.133673  0.000000  0.000000  1.518846  0.000000
# INDUS    1.080296  1.625246  1.667677  0.602467  1.500271
# CHAS     0.885131  0.000000  1.133894  1.112088  1.314286
# NOX      1.013574  1.202153  1.210080  0.873583  1.275885
# RM       0.988884  0.966802  0.951887  1.030015  0.941358
# AGE      1.009800  1.314267  1.311175  0.817584  1.338947
# DIS      0.955795  0.523929  0.547336  1.274735  0.612296
# RAD      0.495810  2.513245  2.410580  0.454317  0.495033
# TAX      0.985472  1.631405  1.636808  0.672865  0.947756
# PTRATIO  0.962379  1.094523  1.094257  0.967815  0.921133
# B        1.071693  0.156080  1.042417  1.090003  0.525820
# LSTAT    0.962451  1.660264  1.412624  0.748150  1.360360

# %%
bottom=df.loc[:, df.columns[0]:df.columns[i]].sum(axis=1).values -
               df.loc[:, df.columns[i]].values,

# %%
i=2

# %%
bottom = df.iloc[:, 0:i].sum(axis=1).values - df.iloc[:, i].values
# Out:
# array([ 1.67552347,  1.13367347,  1.03786488, -0.24876236,  1.00564727,
#         1.00379917,  1.0128914 ,  0.93238798,  0.59847548,  0.98006817,
#         0.96264496,  0.18535658,  1.21009181])

# %%
lift.T.loc[:, lift.T.columns[2]]
# Out:
# CRIM       3.019355
# ZN         0.000000
# INDUS      1.667677
# CHAS       1.133894
# NOX        1.210080
# RM         0.951887
# AGE        1.311175
# DIS        0.547336
# RAD        2.410580
# TAX        1.636808
# PTRATIO    1.094257
# B          1.042417
# LSTAT      1.412624
# Name: 2, dtype: float64

# %%
# Call barplot function using one column of the dataframe at a time
    if isinstance(df, pd.DataFrame):                    # Ina: in future, change this to assert?
        bottom = 0
        for i in range(len(df.columns)):

            label=df.columns[i]
            x = df.index.tolist()
            y = df.iloc[:, i]
            bottom = df.iloc[:, 0:i].sum(axis=1).values - df.iloc[:, i].values

            if 'color' in kwargs:                       # use color from kwargs = first choice
                print('kwargs[color] is:',kwargs['color'])
                color = kwargs.pop('color')

            elif plot_color is not None:              # use colors from plot_color list = second choice
                print('plot_color is:',plot_color)
                color = plot_color[i]
            else:                                      # use colors given by cmap = third choice
                print('cmap is:',cmap)
                color = 'red'
            ax.bar(
                x,
                y,
                bottom=bottom,
                color=color,
                label=label,
                **kwargs);

# %%
lift.T.loc[:, lift.T.columns[0]:lift.T.columns[0]].sum(axis=1)
# Out:
# CRIM       0.171292
# ZN         1.133673
# INDUS      1.080296
# CHAS       0.885131
# NOX        1.013574
# RM         0.988884
# AGE        1.009800
# DIS        0.955795
# RAD        0.495810
# TAX        0.985472
# PTRATIO    0.962379
# B          1.071693
# LSTAT      0.962451
# dtype: float64

# %%
river_means.loc['CRIM'].loc[:, river_means.loc['CRIM'].columns[0]:river_means.loc['CRIM'].columns[1]].sum(axis=1)
# Out:
# cluster
# 0     2.293295
# 1    16.346086
# 2    17.123387
# 3     0.464869
# 4     5.341037
# dtype: float64

# %%
river_means.loc['CRIM'].loc[:, river_means.loc['CRIM'].columns[1]].values
# Out:
# array([1.747955  ,        nan, 5.77588625, 0.2289315 , 3.53501   ])

# %% [markdown]
# ## Heatmap

# %%
population_mean = df.drop('cluster', axis=1).mean()
lift = means.div(population_mean)

# %%
fig, ax = vh.plot(df=lift.T, kind='heatmap', xlabel='Cluster number', 
                     title='Lift')

# %% [markdown]
# Any `kwargs` for `seaborn.heatmap()` work for the function too, such as `annot` and ` xrotation`

# %%
fig, ax = vh.plot(df=lift.T, kind='heatmap', xlabel='Cluster number', 
                     title='Lift', xrotation=0, annot=True)

# %% [markdown]
# ### Using `vh.heatmap()` directly

# %%
ax = vh.heatmap(lift.T, ax=ax)

# %%
fig, ax = vh.heatmap(lift.T)

# %% [markdown]
# ## Box plots

# %%
fig, ax = vh.plot(df.cluster, df.CRIM, kind='boxplot', ylim=(0,40))

# %% [markdown]
# # Demo of `vh.vhDvhisDF`

# %%
feature_labels = ['Per-capita crime rate',
                 'Proportion of residential land zoned for lots over 25,000 sq.ft.',
                 'Proportion of non-retail business acres per town',
                 'Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)',
                 'Nitric oxides concentration (parts per 10 million)',
                 'Average number of rooms per dwelling',
                 'Proportion of owner-occupied units built prior to 1940',
                'Weighted distances to five Boston employment centres',
                'Index of accessibility to radial highways',
                "Full-value property-tax rate per $10,000",
                'Pupil-teacher ratio by town',
                '1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town',
                'Percent of lower status of the population',
                "Median value of owner-occupied homes in $1000's"]

column_labels = dict(zip(df.columns, feature_labels))

# %%
proportion_features = ['ZN','INDUS','AGE','LSTAT']

# %%
plot_df = vh.VisDF(df, column_labels=column_labels, cluster_label='cluster')

# %% [markdown]
# ## Relationship between categorical and continuous variables (e.g. cluster assigment and feature)

# %% [markdown]
# ### Calculate lift, percent increase, absolute difference from population of group statistics

# %%
comparison = plot_df.compare_categories(category='cluster')

# %%
comparison.keys()
# Out:
# dict_keys(['lift', 'percent_increase', 'absolute_difference', 'actual'])

# %%
comparison['actual']
# Out:
#               CRIM         ZN      INDUS      CHAS       NOX        RM  \
# cluster
# 0        16.346086   0.000000  18.100000  0.000000  0.666829  6.076000
# 1         0.235398  17.259615   6.709538  0.076923  0.484572  6.473265
# 2        10.910511   0.000000  18.572549  0.078431  0.671225  5.982265
# 3         1.963207   0.000000  16.708182  0.090909  0.707727  5.916091
# 4         0.618969  12.882653  12.031020  0.061224  0.562224  6.214776
#
#                AGE       DIS        RAD         TAX    PTRATIO           B  \
# cluster
# 0        90.125714  1.988334  24.000000  666.000000  20.200000   55.669714
# 1        56.065769  4.837673   4.338462  274.688462  17.861538  388.775654
# 2        89.913725  2.077164  23.019608  668.205882  20.195098  371.803039
# 3        91.818182  2.323691   4.727273  386.909091  17.000000  187.546364
# 4        69.246939  3.627282   4.734694  402.306122  17.761224  382.245204
#
#              LSTAT
# cluster
# 0        21.007429
# ...

# %%
comparison['lift']
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# cluster
# 0        4.523586  0.000000  1.625246  0.000000  1.202153  0.966802  1.314267
# 1        0.065144  1.518846  0.602467  1.112088  0.873583  1.030015  0.817584
# 2        3.019355  0.000000  1.667677  1.133894  1.210080  0.951887  1.311175
# 3        0.543294  0.000000  1.500271  1.314286  1.275885  0.941358  1.338947
# 4        0.171292  1.133673  1.080296  0.885131  1.013574  0.988884  1.009800
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT
# cluster
# 0        0.523929  2.513245  1.631405  1.094523  0.156080  1.660264
# 1        1.274735  0.454317  0.672865  0.967815  1.090003  0.748150
# 2        0.547336  2.410580  1.636808  1.094257  1.042417  1.412624
# 3        0.612296  0.495033  0.947756  0.921133  0.525820  1.360360
# 4        0.955795  0.495810  0.985472  0.962379  1.071693  0.962451

# %% [markdown]
# ### Heatmap of variable means by category

# %%
fig, ax = plot_df.category_heatmap(category='cluster', metric='actual', 
                                   transpose=True, xrotation=0)

# %% [markdown]
# ### Heatmap of lift

# %% [markdown]
# Actual values are usually hard to visualize like this because they may be different ordres of magnitude. We can plot lift as:
#
# $$ lift = \frac{\bar{v}_c}{\bar{v}_{pop}} $$
#
# where $v$ represents a variable such as the per capita crime rate, $\bar{v}_c$ is the mean of that variable for a particular cluster, $c$, and $\bar{v}_{pop}$ is the mean for the population.

# %%
fig, ax = plot_df.category_heatmap(category='cluster', metric='lift', 
                                   transpose=True)

# %% [markdown]
# ## Box plots

# %%
fig, ax = plot_df.subplots([["cluster","CRIM"]], kind='boxplot', 
                           main_title='Distribution of per-capita crime rate by cluster')

# %% [markdown]
# ## Subplots

# %% [markdown]
# Column label mapping will now occur in any figures created through the `vh.VisDF` object, `plot_df`.

# %% [markdown]
# ### Same type of plot

# %%
fig, ax = plot_df.subplots(proportion_features, kind='hist', log=True,
                           main_title='Distribution of proportional variables')

# %% [markdown]
# ### Different types of plots

# %%
fig, ax = plot_df.subplots([['CRIM','AGE'],['AGE'], 'CRIM', ['cluster', 'AGE']], kind=['scatter','hist', 'hist', 'boxplot'], 
                           main_title='Per capita crime rate by town and Proportion of owner-occupied units built prior to 1940', layout=(2,2))

# %% [markdown]
# ### Subplots with categorical counts

# %%
fig, ax = plot_df.subplots(['RAD', 'cluster'], kind='barh', counts=True,
                           main_title='Counts of categorical variables')
